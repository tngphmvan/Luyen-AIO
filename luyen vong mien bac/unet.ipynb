# %%
from transformers.models.d_fine import DFineConfig, DFineForObjectDetection
config = DFineConfig()
model = DFineForObjectDetection(config)
print(model)
# Out:
# `backbone_config` and `backbone` are `None`. Initializing the config with the default `HGNet-V2` backbone.
# DFineForObjectDetection(
#   (model): DFineModel(
#     (backbone): DFineConvEncoder(
#       (model): HGNetV2Backbone(
#         (embedder): HGNetV2Embeddings(
#           (stem1): HGNetV2ConvLayer(
#             (convolution): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (normalization): DFineFrozenBatchNorm2d()
#             (activation): ReLU()
#             (lab): Identity()
#           )
#           (stem2a): HGNetV2ConvLayer(
#             (convolution): Conv2d(32, 16, kernel_size=(2, 2), stride=(1, 1), bias=False)
#             (normalization): DFineFrozenBatchNorm2d()
#             (activation): ReLU()
#             (lab): Identity()
#           )
#           (stem2b): HGNetV2ConvLayer(
#             (convolution): Conv2d(16, 32, kernel_size=(2, 2), stride=(1, 1), bias=False)
# ...
